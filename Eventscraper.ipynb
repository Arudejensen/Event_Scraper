# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import os
import re

# %%
url_cafe1001 = "https://www.cafe1001.co.uk/music/"
url_dalston = "https://dalstonsuperstore.com/whats-on/"

# %%
page = urlopen(url_cafe1001)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

# %%
events = soup.find_all(["div", "li", "h2", "h3"], class_ = re.compile(r"event"))

# %%
titles = soup.find_all(["div", "li", "h2", "h3"], class_ = re.compile(r"event.*title"))

# %%
a_elements = soup.find_all(["a"], class_ = re.compile(r"event"))
links = [link.get("href") for link in a_elements]

# %%
dates = soup.find_all(["div", "li", "h2", "h3"], class_ = re.compile(r"event.*date"))

# %%
titles
# Out:
# [<h2 class="event-listings--title text-center f-scotch">What's On</h2>,
#  <div class="event-title">Emanuel Pavlova, Bena</div>,
#  <div class="event-title">Off The Cuff: OTC Residents, Quench, Nida, Moze</div>,
#  <div class="event-title">BYOV – Bring Your Own Vinyl</div>,
#  <div class="event-title">BLUSH</div>,
#  <div class="event-title">Megan Leo</div>,
#  <div class="event-title">Jake De Glanville &amp; Friends</div>,
#  <div class="event-title">Far Corners (Daniele &amp; Goes by Kamar)</div>,
#  <div class="event-title">Back It Up! – Vinyl Workshops</div>,
#  <div class="event-title">The MF DOOM LP</div>,
#  <div class="event-title">Arnie Wrong</div>,
#  <div class="event-title">1001 x The Moth Club: Mystic State, Tubby Isiah, Hatti Vatti</div>,
#  <div class="event-title">EFG London Jazz Fest with Santa Leticia &amp; Peirre Antoine</div>,
#  <div class="event-title">BYOV – Bring Your Own Vinyl</div>,
#  <div class="event-title">Roberta Cutolo</div>,
# ...

# %%
for event in events:
    print(event.get_text(strip = True))
# Out:
# 02SaturdayIssa M-A.D Haus Party - TIL 4AM
# 02SaturdayIssa M-A.D Haus Party - TIL 4AM
# 03SundayDrag Brunch with Loren Dell'Arco + Perle Rare
# 03SundayDrag Brunch with Loren Dell'Arco + Perle Rare
# 03SundaySorryNotSorry Sundays!
# 03SundaySorryNotSorry Sundays!
# 04MondayVINYL BITCH: OPEN DECKS
# 04MondayVINYL BITCH: OPEN DECKS
# 06WednesdayTransmissions presents: PULSE (2001) + INTRO BY JEI DEGENHARDT
# 06WednesdayTransmissions presents: PULSE (2001) + INTRO BY JEI DEGENHARDT
# 06WednesdayBodySwap
# 06WednesdayBodySwap
# 07ThursdayHoofy Endings - TOILET RAVE
# 07ThursdayHoofy Endings - TOILET RAVE
# 08FridayCLUB TANTRUM - TIL 4AM
# 08FridayCLUB TANTRUM - TIL 4AM
# 09SaturdayDrag Brunch with Virgin X + Femmi!
# 09SaturdayDrag Brunch with Virgin X + Femmi!
# 09SaturdayFèmmme Fraîche
# 09SaturdayFèmmme Fraîche
# 10SundayBonk & Pasty's Big Old Brunch!
# 10SundayBonk & Pasty's Big Old Brunch!
# 10SundayAll Nite Long: Nick Clev
# 10SundayAll Nite Long: Nick Clev
# ...

# %%
print(html)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" class="night-mode">
# <head>
# 	<meta charset="UTF-8" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no" />
# 	<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tiny-slider/2.9.2/tiny-slider.css">
# 	<link rel="stylesheet" type="text/css" href="https://dalstonsuperstore.com/wp-content/themes/dalston-superstore/style.css?ver=1730585450" />
# 	<link href="https://fonts.googleapis.com/css2?family=Arimo:wght@700&display=swap" rel="stylesheet">
# 	<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
#
# 	<!-- This site is optimized with the Yoast SEO plugin v20.12 - https://yoast.com/wordpress/plugins/seo/ -->
# 	<title>What’s On - Dalston Superstore</title>
# 	<link rel="canonical" href="https://dalstonsuperstore.com/whats-on/" />
# 	<meta property="og:locale" content="en_US" />
# 	<meta property="og:type" content="article" />
# ...
